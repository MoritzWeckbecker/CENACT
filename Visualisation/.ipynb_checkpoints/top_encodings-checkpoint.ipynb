# %%
import os
import json
import numpy as np
import pandas as pd
import altair as alt

# %%
# Uncomment if you are using dark jupyter lab/notebook theme
alt.renderers.set_embed_options(theme='dark')
alt.data_transformers.disable_max_rows()
# Out:
# DataTransformerRegistry.enable('default')

# %% [markdown]
# # Data importing and filtering

# %%
path_cenact_results = os.path.join(
    '..', 'Results', 'CENACT_f1_score_overview.csv')
path_other_encodings_results = os.path.join(
    '..', 'Data', 'Visualization_data', 'peptidereactor_vis_data',
    'hm_bio_data.json')

# %%
df_cenact_results = pd.read_csv(path_cenact_results).dropna(subset=['F1'])
df_cenact_results.drop(['Encoding_max', 'bio_field', 'is_imbalanced'],
                       axis=1, inplace=True)  # Removing extra columns
df_cenact_results
# Out:
#              Dataset    Encoding        F1            type
# 0       ace_vaxinpad  cenact_hyd  0.816760  sequence based
# 1         acp_anticp  cenact_hyd  0.786909  sequence based
# 2           acp_iacp  cenact_hyd  0.749565  sequence based
# 3          acp_mlacp  cenact_hyd  0.589155  sequence based
# 4        afp_amppred  cenact_hyd  0.769917  sequence based
# ..               ...         ...       ...             ...
# 181           hiv_v3   cenact_dd  0.800079  sequence based
# 182     isp_il10pred   cenact_dd  0.475933  sequence based
# 183  nep_neuropipred   cenact_dd  0.743103  sequence based
# 184        pip_pipel   cenact_dd  0.347928  sequence based
# 185         tce_zhao   cenact_dd  0.431818  sequence based
#
# [186 rows x 4 columns]

# %%
df_other_encodings_results = pd.read_json(path_other_encodings_results).dropna(
    subset=['F1'])
df_other_encodings_results.drop(
    ['Encoding_max', 'index', 'type_field', 'missing', 'bio_field',
     'is_imbalanced'],
    axis=1, inplace=True)  # Removing extra columns

df_other_encodings_results = df_other_encodings_results[
    df_other_encodings_results['F1'] != 'separator']
df_other_encodings_results
# Out:
#        Dataset Encoding        F1             type
# 0       hiv_v3   dist_f  0.980728   sequence based
# 1       hiv_v3   blomap  0.978587   sequence based
# 2       hiv_v3   paac_l   0.97619   sequence based
# 3       hiv_v3   blosum  0.976344   sequence based
# 4       hiv_v3   distan  0.925277  structure based
# ...        ...      ...       ...              ...
# 5175  tce_zhao   cksaag  0.414286   sequence based
# 5176  tce_zhao   qsorde  0.333333   sequence based
# 5177  tce_zhao   fldpc_  0.572727   sequence based
# 5178  tce_zhao     ctdd  0.333333   sequence based
# 5179  tce_zhao     qsar  0.090909  structure based
#
# [4488 rows x 4 columns]

# %%
df_combined_results = pd.concat(
    [df_cenact_results, df_other_encodings_results], axis=0)
df_combined_results
# Out:
#            Dataset    Encoding        F1             type
# 0     ace_vaxinpad  cenact_hyd   0.81676   sequence based
# 1       acp_anticp  cenact_hyd  0.786909   sequence based
# 2         acp_iacp  cenact_hyd  0.749565   sequence based
# 3        acp_mlacp  cenact_hyd  0.589155   sequence based
# 4      afp_amppred  cenact_hyd  0.769917   sequence based
# ...            ...         ...       ...              ...
# 5175      tce_zhao      cksaag  0.414286   sequence based
# 5176      tce_zhao      qsorde  0.333333   sequence based
# 5177      tce_zhao      fldpc_  0.572727   sequence based
# 5178      tce_zhao        ctdd  0.333333   sequence based
# 5179      tce_zhao        qsar  0.090909  structure based
#
# [4674 rows x 4 columns]

# %% [markdown]
# # Splitting the data according to the type (sequence-based vs. structure-based)

# %%
df_sequence_encodings = df_combined_results[
    df_combined_results['type'] == 'sequence based'].reset_index(drop=True)
df_sequence_encodings.drop('type', axis=1, inplace=True)
df_sequence_encodings
# Out:
#            Dataset    Encoding        F1
# 0     ace_vaxinpad  cenact_hyd   0.81676
# 1       acp_anticp  cenact_hyd  0.786909
# 2         acp_iacp  cenact_hyd  0.749565
# 3        acp_mlacp  cenact_hyd  0.589155
# 4      afp_amppred  cenact_hyd  0.769917
# ...            ...         ...       ...
# 3769      tce_zhao      dist_f  0.381818
# 3770      tce_zhao      cksaag  0.414286
# 3771      tce_zhao      qsorde  0.333333
# 3772      tce_zhao      fldpc_  0.572727
# 3773      tce_zhao        ctdd  0.333333
#
# [3774 rows x 3 columns]

# %%
df_structure_encodings = df_combined_results[
    df_combined_results['type'] == 'structure based'].reset_index(drop=True)
df_structure_encodings.drop('type', axis=1, inplace=True)
df_structure_encodings['F1'] = pd.to_numeric(df_structure_encodings['F1'])
df_structure_encodings
# Out:
#       Dataset Encoding        F1
# 0      hiv_v3   distan  0.925277
# 1      hiv_v3   delaun  0.926829
# 2      hiv_v3     ssec  0.920000
# 3      hiv_v3   electr  0.926122
# 4      hiv_v3   disord  0.920000
# ..        ...      ...       ...
# 895  tce_zhao   distan  0.333333
# 896  tce_zhao      asa  0.000000
# 897  tce_zhao     sseb  0.066667
# 898  tce_zhao   disord  0.200000
# 899  tce_zhao     qsar  0.090909
#
# [900 rows x 3 columns]

# %%
df_sequence_encodings['F1'] = pd.to_numeric(df_sequence_encodings['F1'])
df_sequence_encodings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3774 entries, 0 to 3773
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Dataset   3774 non-null   object
#  1   Encoding  3774 non-null   object
#  2   F1        3774 non-null   float64
# dtypes: float64(1), object(2)
# memory usage: 88.6+ KB

# %% [markdown]
# # Data sorting and exporting
# ## Aggregation on data sets per encoding

# %%
df_sorted_sequence_encodings = df_sequence_encodings.groupby(
    'Encoding')[['F1']].median().sort_values('F1', ascending=False)
df_sorted_sequence_encodings
# Out:
#                     F1
# Encoding
# dist_f        0.888316
# cksaap        0.881567
# dpc           0.872812
# psekraac      0.872761
# dde           0.864251
# qsorde        0.859727
# tpc           0.859080
# ngram_        0.856912
# apaac_        0.854452
# paac_l        0.845311
# binary        0.840302
# ctriad        0.839711
# ksctri        0.837366
# waac_a        0.834585
# aac           0.831702
# fldpc_        0.828188
# ctdd          0.827441
# cksaag        0.823189
# gtpc          0.816525
# ctdt          0.815965
# gdpc          0.806208
# ctdc          0.804434
# nmbrot        0.800000
# aainde        0.799147
# fft_aa        0.779505
# flgc_a        0.773763
# cenact_nohyd  0.773716
# cenact_hyd    0.771042
# cenact_dd     0.768236
# socnum        0.762086
# geary_        0.745778
# cgr_re        0.745628
# moran_        0.743752
# gaac          0.734044
# egaac_        0.729960
# eaac_w        0.729595
# blomap        0.727430
# zscale        0.724898
# blosum        0.713963

# %%
df_sorted_structure_encodings = df_structure_encodings.groupby(
    'Encoding')[['F1']].median().sort_values('F1', ascending=False)

# %%
print(df_sorted_sequence_encodings.to_latex())
# Out:
# \begin{tabular}{lr}
# \toprule
#  & F1 \\
# Encoding &  \\
# \midrule
# dist_f & 0.888316 \\
# cksaap & 0.881567 \\
# dpc & 0.872812 \\
# psekraac & 0.872761 \\
# dde & 0.864251 \\
# qsorde & 0.859727 \\
# tpc & 0.859080 \\
# ngram_ & 0.856912 \\
# apaac_ & 0.854452 \\
# paac_l & 0.845311 \\
# binary & 0.840302 \\
# ctriad & 0.839711 \\
# ksctri & 0.837366 \\
# waac_a & 0.834585 \\
# aac & 0.831702 \\
# fldpc_ & 0.828188 \\
# ctdd & 0.827441 \\
# cksaag & 0.823189 \\
# gtpc & 0.816525 \\
# ctdt & 0.815965 \\
# gdpc & 0.806208 \\
# ctdc & 0.804434 \\
# nmbrot & 0.800000 \\
# aainde & 0.799147 \\
# fft_aa & 0.779505 \\
# flgc_a & 0.773763 \\
# cenact_nohyd & 0.773716 \\
# cenact_hyd & 0.771042 \\
# cenact_dd & 0.768236 \\
# socnum & 0.762086 \\
# geary_ & 0.745778 \\
# cgr_re & 0.745628 \\
# moran_ & 0.743752 \\
# gaac & 0.734044 \\
# egaac_ & 0.729960 \\
# eaac_w & 0.729595 \\
# blomap & 0.727430 \\
# zscale & 0.724898 \\
# blosum & 0.713963 \\
# \bottomrule
# \end{tabular}

# %%
print(df_sorted_structure_encodings.to_latex())
# Out:
# \begin{tabular}{lr}
# \toprule
#  & F1 \\
# Encoding &  \\
# \midrule
# delaun & 0.789711 \\
# qsar & 0.726743 \\
# electr & 0.704956 \\
# distan & 0.654590 \\
# disord & 0.574943 \\
# asa & 0.571013 \\
# ta & 0.566491 \\
# sseb & 0.565670 \\
# ssec & 0.530964 \\
# \bottomrule
# \end{tabular}

# %% [markdown]
# ## Aggregation on encodings per data set

# %%
df_combined_results.drop('type', axis=1, inplace=True)
df_combined_results
# Out:
#            Dataset    Encoding        F1
# 0     ace_vaxinpad  cenact_hyd   0.81676
# 1       acp_anticp  cenact_hyd  0.786909
# 2         acp_iacp  cenact_hyd  0.749565
# 3        acp_mlacp  cenact_hyd  0.589155
# 4      afp_amppred  cenact_hyd  0.769917
# ...            ...         ...       ...
# 5175      tce_zhao      cksaag  0.414286
# 5176      tce_zhao      qsorde  0.333333
# 5177      tce_zhao      fldpc_  0.572727
# 5178      tce_zhao        ctdd  0.333333
# 5179      tce_zhao        qsar  0.090909
#
# [4674 rows x 3 columns]

# %%
df_sorted_per_dataset_top_1 = df_combined_results.sort_values(
    'F1', ascending=False).groupby(
    'Dataset', as_index=False).head(1).sort_values(
    'Dataset').reset_index(drop=True)

df_sorted_per_dataset_top_1
# Out:
#                 Dataset      Encoding        F1
# 0          ace_vaxinpad        cksaap   0.95833
# 1            acp_anticp        apaac_  0.893867
# 2              acp_iacp        paac_l  0.901961
# 3             acp_mlacp        qsorde  0.755599
# 4           afp_amppred        cksaap  0.910436
# ..                  ...           ...       ...
# 57            sol_ecoli     cenact_dd  0.722274
# 58             tce_zhao        aainde  0.666667
# 59           toxinpred2     cenact_dd  0.747344
# 60  toxinpred_swissprot  cenact_nohyd  0.835506
# 61     toxinpred_trembl  cenact_nohyd  0.766152
#
# [62 rows x 3 columns]

# %%
print(df_sorted_per_dataset_top_1.to_latex())
# Out:
# \begin{tabular}{llll}
# \toprule
#  & Dataset & Encoding & F1 \\
# \midrule
# 0 & ace_vaxinpad & cksaap & 0.958330 \\
# 1 & acp_anticp & apaac_ & 0.893867 \\
# 2 & acp_iacp & paac_l & 0.901961 \\
# 3 & acp_mlacp & qsorde & 0.755599 \\
# 4 & afp_amppred & cksaap & 0.910436 \\
# 5 & afp_antifp & dist_f & 0.895777 \\
# 6 & ai4avp_2 & cenact_hyd & 0.716022 \\
# 7 & aip_aippred & dde & 0.624602 \\
# 8 & aip_antiinflam & dde & 0.669810 \\
# 9 & amp_antibp & cksaap & 0.958332 \\
# 10 & amp_antibp2 & qsorde & 0.924050 \\
# 11 & amp_csamp & dist_f & 0.980392 \\
# 12 & amp_fernandes & cenact_dd & 0.822134 \\
# 13 & amp_gonzales & gdpc & 0.888889 \\
# 14 & amp_iamp2l & dist_f & 0.817127 \\
# 15 & amp_modlamp & cksaap & 0.934132 \\
# 16 & amy_albase & cenact_nohyd & 0.927475 \\
# 17 & amy_hex & cenact_hyd & 0.691899 \\
# 18 & atb_antitbp & cksaag & 0.832476 \\
# 19 & atb_iantitb & cksaap & 0.800000 \\
# 20 & avp_amppred & cksaap & 0.880951 \\
# 21 & avp_avppred & cksaap & 0.871587 \\
# 22 & bce_ibce & dde & 0.654593 \\
# 23 & c2pred & cenact_dd & 0.726270 \\
# 24 & cpp_cellppd & dist_f & 0.903024 \\
# 25 & cpp_cellppdmod & dist_f & 0.933098 \\
# 26 & cpp_cppredfl & dist_f & 0.909049 \\
# 27 & cpp_kelmcpp & cksaap & 0.851957 \\
# 28 & cpp_mixed & cenact_dd & 0.894241 \\
# 29 & cpp_mlcpp & cksaap & 0.849600 \\
# 30 & cpp_mlcppue & dist_f & 0.702703 \\
# 31 & cpp_sanders & dist_f & 0.893617 \\
# 32 & cppsite2 & cenact_nohyd & 0.835619 \\
# 33 & effectorp & cenact_hyd & 0.568061 \\
# 34 & foldamer_b & cenact_dd & 0.968870 \\
# 35 & hem_hemopi & apaac_ & 0.928230 \\
# 36 & hiv_3tc & qsar & 0.974359 \\
# 37 & hiv_abc & qsar & 0.972973 \\
# 38 & hiv_apv & qsar & 0.988372 \\
# 39 & hiv_azt & qsar & 0.976378 \\
# 40 & hiv_bevirimat & qsar & 1.000000 \\
# 41 & hiv_d4t & qsar & 0.985075 \\
# 42 & hiv_ddi & qsar & 0.975805 \\
# 43 & hiv_dlv & qsar & 0.983425 \\
# 44 & hiv_efv & qsar & 0.983425 \\
# 45 & hiv_idv & qsar & 0.993506 \\
# 46 & hiv_lpv & qsar & 0.988635 \\
# 47 & hiv_nfv & qsar & 0.991736 \\
# 48 & hiv_nvp & qsar & 0.982036 \\
# 49 & hiv_protease & ngram_ & 0.792453 \\
# 50 & hiv_rtv & qsar & 0.992806 \\
# 51 & hiv_sqv & qsar & 0.989011 \\
# 52 & hiv_v3 & qsar & 0.991342 \\
# 53 & isp_il10pred & dde & 0.680136 \\
# 54 & nep_neuropipred & cksaap & 0.882183 \\
# 55 & perm_cyc & cenact_nohyd & 0.851943 \\
# 56 & pip_pipel & dde & 0.559835 \\
# 57 & sol_ecoli & cenact_dd & 0.722274 \\
# 58 & tce_zhao & aainde & 0.666667 \\
# 59 & toxinpred2 & cenact_dd & 0.747344 \\
# 60 & toxinpred_swissprot & cenact_nohyd & 0.835506 \\
# 61 & toxinpred_trembl & cenact_nohyd & 0.766152 \\
# \bottomrule
# \end{tabular}

# %%
df_sorted_per_dataset_top_3 = df_combined_results.sort_values(
    'F1', ascending=False).groupby(
    'Dataset', as_index=False).head(3).sort_values(
    'Dataset').reset_index(drop=True)

df_sorted_per_dataset_top_3
# Out:
#                  Dataset      Encoding        F1
# 0           ace_vaxinpad        cksaap   0.95833
# 1           ace_vaxinpad        dist_f  0.942619
# 2           ace_vaxinpad        cksaap   0.95833
# 3             acp_anticp        paac_l  0.890097
# 4             acp_anticp        apaac_  0.893867
# ..                   ...           ...       ...
# 181  toxinpred_swissprot  cenact_nohyd  0.835506
# 182  toxinpred_swissprot     cenact_dd  0.825976
# 183     toxinpred_trembl  cenact_nohyd  0.766152
# 184     toxinpred_trembl     cenact_dd  0.744815
# 185     toxinpred_trembl    cenact_hyd  0.756115
#
# [186 rows x 3 columns]

# %%
df_sorted_per_dataset_top_3['Encoding_F1'] = df_sorted_per_dataset_top_3[
    'Encoding'] + ' ' + df_sorted_per_dataset_top_3['F1'].astype(str)

df_sorted_per_dataset_top_3 = df_sorted_per_dataset_top_3.groupby(
    'Dataset', as_index=False)['Encoding_F1'].apply(list).reset_index(drop=True)

df_sorted_per_dataset_top_3 = df_sorted_per_dataset_top_3['Dataset'].to_frame(
    ).join(
    pd.DataFrame(df_sorted_per_dataset_top_3['Encoding_F1'].to_list(),
                 columns=['1st Place', '2nd Place', '3rd Place']))

df_sorted_per_dataset_top_3
# Out:
#                 Dataset                        1st Place  \
# 0          ace_vaxinpad        cksaap 0.9583304396000001
# 1            acp_anticp              paac_l 0.8900966184
# 2              acp_iacp              dist_f 0.8979591837
# 3             acp_mlacp               waac_a 0.741025641
# 4           afp_amppred              dist_f 0.9025079148
# ..                  ...                              ...
# 57            sol_ecoli    cenact_hyd 0.7222739168362897
# 58             tce_zhao        aainde 0.6666666667000001
# 59           toxinpred2  cenact_nohyd 0.7466785371866869
# 60  toxinpred_swissprot    cenact_hyd 0.8317068077404983
# 61     toxinpred_trembl   cenact_nohyd 0.766151777421983
#
#                          2nd Place                       3rd Place
# 0              dist_f 0.9426190956       cksaap 0.9583304396000001
# 1        apaac_ 0.8938673342000001       apaac_ 0.8938673342000001
# 2              paac_l 0.9019607843             paac_l 0.9019607843
# 3        qsorde 0.7555994730000001       qsorde 0.7555994730000001
# 4              cksaap 0.9104362061             cksaap 0.9104362061
# ..                             ...                             ...
# 57    cenact_dd 0.7222739168362897  cenact_nohyd 0.714074074074074
# 58       aainde 0.6666666667000001             zscale 0.6076923077
# 59   cenact_hyd 0.7473438956197576    cenact_dd 0.7473438956197576
# 60  cenact_nohyd 0.835505824274132     cenact_dd 0.825975884630356
# 61    cenact_dd 0.7448149874938055   cenact_hyd 0.7561146051712089
#
# [62 rows x 4 columns]

# %%
df_sorted_per_dataset_top_3[
    ['1st Encoding', '1st F1']] = df_sorted_per_dataset_top_3[
    '1st Place'].str.split(' ', expand=True)
df_sorted_per_dataset_top_3[
    ['2nd Encoding', '2nd F1']] = df_sorted_per_dataset_top_3[
    '2nd Place'].str.split(' ', expand=True)
df_sorted_per_dataset_top_3[
    ['3rd Encoding', '3rd F1']] = df_sorted_per_dataset_top_3[
    '3rd Place'].str.split(' ', expand=True)
df_sorted_per_dataset_top_3
# Out:
#                 Dataset                        1st Place  \
# 0          ace_vaxinpad        cksaap 0.9583304396000001
# 1            acp_anticp              paac_l 0.8900966184
# 2              acp_iacp              dist_f 0.8979591837
# 3             acp_mlacp               waac_a 0.741025641
# 4           afp_amppred              dist_f 0.9025079148
# ..                  ...                              ...
# 57            sol_ecoli    cenact_hyd 0.7222739168362897
# 58             tce_zhao        aainde 0.6666666667000001
# 59           toxinpred2  cenact_nohyd 0.7466785371866869
# 60  toxinpred_swissprot    cenact_hyd 0.8317068077404983
# 61     toxinpred_trembl   cenact_nohyd 0.766151777421983
#
#                          2nd Place                       3rd Place  \
# 0              dist_f 0.9426190956       cksaap 0.9583304396000001
# 1        apaac_ 0.8938673342000001       apaac_ 0.8938673342000001
# 2              paac_l 0.9019607843             paac_l 0.9019607843
# 3        qsorde 0.7555994730000001       qsorde 0.7555994730000001
# 4              cksaap 0.9104362061             cksaap 0.9104362061
# ..                             ...                             ...
# 57    cenact_dd 0.7222739168362897  cenact_nohyd 0.714074074074074
# 58       aainde 0.6666666667000001             zscale 0.6076923077
# 59   cenact_hyd 0.7473438956197576    cenact_dd 0.7473438956197576
# 60  cenact_nohyd 0.835505824274132     cenact_dd 0.825975884630356
# 61    cenact_dd 0.7448149874938055   cenact_hyd 0.7561146051712089
#
#     1st Encoding              1st F1  2nd Encoding              2nd F1  \
# 0         cksaap  0.9583304396000001        dist_f        0.9426190956
# 1         paac_l        0.8900966184        apaac_  0.8938673342000001
# 2         dist_f        0.8979591837        paac_l        0.9019607843
# 3         waac_a         0.741025641        qsorde  0.7555994730000001
# 4         dist_f        0.9025079148        cksaap        0.9104362061
# ..           ...                 ...           ...                 ...
# 57    cenact_hyd  0.7222739168362897     cenact_dd  0.7222739168362897
# 58        aainde  0.6666666667000001        aainde  0.6666666667000001
# 59  cenact_nohyd  0.7466785371866869    cenact_hyd  0.7473438956197576
# 60    cenact_hyd  0.8317068077404983  cenact_nohyd   0.835505824274132
# 61  cenact_nohyd   0.766151777421983     cenact_dd  0.7448149874938055
#
#     3rd Encoding              3rd F1
# 0         cksaap  0.9583304396000001
# 1         apaac_  0.8938673342000001
# 2         paac_l        0.9019607843
# 3         qsorde  0.7555994730000001
# 4         cksaap        0.9104362061
# ..           ...                 ...
# 57  cenact_nohyd   0.714074074074074
# 58        zscale        0.6076923077
# 59     cenact_dd  0.7473438956197576
# 60     cenact_dd   0.825975884630356
# 61    cenact_hyd  0.7561146051712089
#
# [62 rows x 10 columns]

# %%
df_sorted_per_dataset_top_3 = df_sorted_per_dataset_top_3.drop(
    ['1st Place', '2nd Place', '3rd Place'], axis=1)
df_sorted_per_dataset_top_3
# Out:
#                 Dataset  1st Encoding              1st F1  2nd Encoding  \
# 0          ace_vaxinpad        cksaap  0.9583304396000001        dist_f
# 1            acp_anticp        paac_l        0.8900966184        apaac_
# 2              acp_iacp        dist_f        0.8979591837        paac_l
# 3             acp_mlacp        waac_a         0.741025641        qsorde
# 4           afp_amppred        dist_f        0.9025079148        cksaap
# ..                  ...           ...                 ...           ...
# 57            sol_ecoli    cenact_hyd  0.7222739168362897     cenact_dd
# 58             tce_zhao        aainde  0.6666666667000001        aainde
# 59           toxinpred2  cenact_nohyd  0.7466785371866869    cenact_hyd
# 60  toxinpred_swissprot    cenact_hyd  0.8317068077404983  cenact_nohyd
# 61     toxinpred_trembl  cenact_nohyd   0.766151777421983     cenact_dd
#
#                 2nd F1  3rd Encoding              3rd F1
# 0         0.9426190956        cksaap  0.9583304396000001
# 1   0.8938673342000001        apaac_  0.8938673342000001
# 2         0.9019607843        paac_l        0.9019607843
# 3   0.7555994730000001        qsorde  0.7555994730000001
# 4         0.9104362061        cksaap        0.9104362061
# ..                 ...           ...                 ...
# 57  0.7222739168362897  cenact_nohyd   0.714074074074074
# 58  0.6666666667000001        zscale        0.6076923077
# 59  0.7473438956197576     cenact_dd  0.7473438956197576
# 60   0.835505824274132     cenact_dd   0.825975884630356
# 61  0.7448149874938055    cenact_hyd  0.7561146051712089
#
# [62 rows x 7 columns]

# %%
print(df_sorted_per_dataset_top_3.to_latex())
# Out:
# \begin{tabular}{llllllll}
# \toprule
#  & Dataset & 1st Encoding & 1st F1 & 2nd Encoding & 2nd F1 & 3rd Encoding & 3rd F1 \\
# \midrule
# 0 & ace_vaxinpad & cksaap & 0.9583304396000001 & dist_f & 0.9426190956 & cksaap & 0.9583304396000001 \\
# 1 & acp_anticp & paac_l & 0.8900966184 & apaac_ & 0.8938673342000001 & apaac_ & 0.8938673342000001 \\
# 2 & acp_iacp & dist_f & 0.8979591837 & paac_l & 0.9019607843 & paac_l & 0.9019607843 \\
# 3 & acp_mlacp & waac_a & 0.741025641 & qsorde & 0.7555994730000001 & qsorde & 0.7555994730000001 \\
# 4 & afp_amppred & dist_f & 0.9025079148 & cksaap & 0.9104362061 & cksaap & 0.9104362061 \\
# 5 & afp_antifp & dist_f & 0.8957765789000001 & dist_f & 0.8957765789000001 & cksaap & 0.8896599088 \\
# 6 & ai4avp_2 & cenact_nohyd & 0.7149224806201551 & cenact_dd & 0.7089169000933707 & cenact_hyd & 0.7160219103046902 \\
# 7 & aip_aippred & dde & 0.6246019108 & dde & 0.6246019108 & egaac_ & 0.5797962649 \\
# 8 & aip_antiinflam & dde & 0.6698097633 & dde & 0.6698097633 & waac_a & 0.6171232305000001 \\
# 9 & amp_antibp & cksaap & 0.958331857 & cksaap & 0.958331857 & qsorde & 0.9560341269 \\
# 10 & amp_antibp2 & qsorde & 0.9240501461 & cksaap & 0.9224995156 & qsorde & 0.9240501461 \\
# 11 & amp_csamp & waac_a & 0.9803921569 & waac_a & 0.9803921569 & dist_f & 0.9803921569 \\
# 12 & amp_fernandes & dist_f & 0.820855615 & dist_f & 0.820855615 & cenact_dd & 0.8221343873517787 \\
# 13 & amp_gonzales & gdpc & 0.8888888889000001 & flgc_a & 0.8888888889000001 & gaac & 0.8888888889000001 \\
# 14 & amp_iamp2l & psekraac & 0.80407112 & dist_f & 0.8171268507 & dist_f & 0.8171268507 \\
# 15 & amp_modlamp & cksaap & 0.9341317365 & dist_f & 0.9284983932 & cksaap & 0.9341317365 \\
# 16 & amy_albase & cenact_dd & 0.925133689839572 & cenact_hyd & 0.925133689839572 & cenact_nohyd & 0.9274752995585454 \\
# 17 & amy_hex & cenact_nohyd & 0.6914125541493248 & cenact_dd & 0.6827646038172352 & cenact_hyd & 0.6918985270049101 \\
# 18 & atb_antitbp & cksaap & 0.8323970037 & cksaag & 0.8324760346000001 & cksaag & 0.8324760346000001 \\
# 19 & atb_iantitb & cksaap & 0.8 & dpc & 0.795808646 & cksaap & 0.8 \\
# 20 & avp_amppred & psekraac & 0.8732394366 & cksaap & 0.8809510036 & cksaap & 0.8809510036 \\
# 21 & avp_avppred & dpc & 0.867768595 & cksaap & 0.8715871215000001 & cksaap & 0.8715871215000001 \\
# 22 & bce_ibce & ctdd & 0.6165048544 & dde & 0.6545929798 & dde & 0.6545929798 \\
# 23 & c2pred & cenact_hyd & 0.7108843537414966 & cenact_nohyd & 0.7232127695703856 & cenact_dd & 0.7262703739213806 \\
# 24 & cpp_cellppd & waac_a & 0.8993710692 & dist_f & 0.9030235615000001 & dist_f & 0.9030235615000001 \\
# 25 & cpp_cellppdmod & dist_f & 0.9330977621000001 & dist_f & 0.9330977621000001 & cksaap & 0.9260554212000001 \\
# 26 & cpp_cppredfl & waac_a & 0.908153702 & dist_f & 0.9090492948000001 & dist_f & 0.9090492948000001 \\
# 27 & cpp_kelmcpp & dist_f & 0.8501207729 & cksaap & 0.8519568151 & cksaap & 0.8519568151 \\
# 28 & cpp_mixed & cenact_dd & 0.8942414174972315 & cenact_nohyd & 0.8942414174972315 & cenact_hyd & 0.8942414174972315 \\
# 29 & cpp_mlcpp & cksaap & 0.8496002206000001 & cksaap & 0.8496002206000001 & dist_f & 0.8402186807 \\
# 30 & cpp_mlcppue & dist_f & 0.7027027027 & psekraac & 0.6933760684 & dist_f & 0.7027027027 \\
# 31 & cpp_sanders & cksaag & 0.8936170213 & fldpc_ & 0.8936170213 & dist_f & 0.8936170213 \\
# 32 & cppsite2 & cenact_hyd & 0.8268136557610242 & cenact_nohyd & 0.835618846694796 & cenact_dd & 0.8062770562770563 \\
# 33 & effectorp & cenact_hyd & 0.568061440677966 & cenact_nohyd & 0.5601638504864311 & cenact_dd & 0.568061440677966 \\
# 34 & foldamer_b & cenact_dd & 0.9688697318007664 & cenact_hyd & 0.9652761032071376 & cenact_nohyd & 0.9617215583406198 \\
# 35 & hem_hemopi & apaac_ & 0.9282296651 & apaac_ & 0.9282296651 & cksaap & 0.9245283019 \\
# 36 & hiv_3tc & cksaap & 0.8994221741 & qsar & 0.9743589744000001 & qsar & 0.9743589744000001 \\
# 37 & hiv_abc & cksaap & 0.8550420168 & qsar & 0.9729729730000001 & qsar & 0.9729729730000001 \\
# 38 & hiv_apv & qsar & 0.9883720930000001 & binary & 0.8971394984000001 & qsar & 0.9883720930000001 \\
# 39 & hiv_azt & qsar & 0.9763779528000001 & cksaap & 0.8988188976 & qsar & 0.9763779528000001 \\
# 40 & hiv_bevirimat & cenact_nohyd & 0.7894736842105263 & qsar & 1.0 & qsar & 1.0 \\
# 41 & hiv_d4t & qsar & 0.9850746269 & qsar & 0.9850746269 & psekraac & 0.8837209302000001 \\
# 42 & hiv_ddi & qsar & 0.975804878 & qsar & 0.975804878 & cgr_re & 0.7983739837 \\
# 43 & hiv_dlv & cksaap & 0.9226783579000001 & qsar & 0.9834254144000001 & qsar & 0.9834254144000001 \\
# 44 & hiv_efv & qsar & 0.9834254144000001 & cksaap & 0.9456521739 & qsar & 0.9834254144000001 \\
# 45 & hiv_idv & binary & 0.9328828829 & qsar & 0.9935062197000001 & qsar & 0.9935062197000001 \\
# 46 & hiv_lpv & dist_f & 0.9195402299000001 & qsar & 0.9886348960000001 & qsar & 0.9886348960000001 \\
# 47 & hiv_nfv & cksaap & 0.9322033898000001 & qsar & 0.9917355372000001 & qsar & 0.9917355372000001 \\
# 48 & hiv_nvp & qsar & 0.9820359281000001 & qsar & 0.9820359281000001 & cksaap & 0.94431826 \\
# 49 & hiv_protease & ngram_ & 0.7924528302 & ngram_ & 0.7924528302 & aainde & 0.5333333333 \\
# 50 & hiv_rtv & binary & 0.9580399061 & qsar & 0.9928057554 & qsar & 0.9928057554 \\
# 51 & hiv_sqv & qsar & 0.9890109890000001 & qsar & 0.9890109890000001 & binary & 0.926133979 \\
# 52 & hiv_v3 & qsar & 0.9913419913 & qsar & 0.9913419913 & aainde & 0.9827586207000001 \\
# 53 & isp_il10pred & dde & 0.6801360544 & egaac_ & 0.6219219219000001 & dde & 0.6801360544 \\
# 54 & nep_neuropipred & cksaap & 0.8821829352 & dist_f & 0.8744606414 & cksaap & 0.8821829352 \\
# 55 & perm_cyc & cenact_dd & 0.8504477420056666 & cenact_nohyd & 0.8519429697334574 & cenact_hyd & 0.8510066296118886 \\
# 56 & pip_pipel & zscale & 0.49902723740000005 & dde & 0.5598353909 & dde & 0.5598353909 \\
# 57 & sol_ecoli & cenact_hyd & 0.7222739168362897 & cenact_dd & 0.7222739168362897 & cenact_nohyd & 0.714074074074074 \\
# 58 & tce_zhao & aainde & 0.6666666667000001 & aainde & 0.6666666667000001 & zscale & 0.6076923077 \\
# 59 & toxinpred2 & cenact_nohyd & 0.7466785371866869 & cenact_hyd & 0.7473438956197576 & cenact_dd & 0.7473438956197576 \\
# 60 & toxinpred_swissprot & cenact_hyd & 0.8317068077404983 & cenact_nohyd & 0.835505824274132 & cenact_dd & 0.825975884630356 \\
# 61 & toxinpred_trembl & cenact_nohyd & 0.766151777421983 & cenact_dd & 0.7448149874938055 & cenact_hyd & 0.7561146051712089 \\
# \bottomrule
# \end{tabular}

# %%
######################################################################
######################################################################
# TODO:
# Check why this table has 62 data sets while the previous one has 61
######################################################################
######################################################################
